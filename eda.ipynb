# %%
import pandas

# %% [markdown]
# ## Carga de datos
# Se cargan los datos de los 3 años de la linea 144.

# %%
l_2021 = pandas.read_csv("dataset/linea144-2021.csv")
l_2022 = pandas.read_csv("dataset/linea144-2022.csv")
l_2023 = pandas.read_csv("dataset/linea144-2023.csv")

# %%
l_2021.head()

# %%
l_2022.head()

# %%
l_2023.head()

# %% [markdown]
# ## Inspeccion inicial y limpieza de datos

# %%
l_2021.info()

# %%
l_2021.describe()

# %%
l_2021.isnull().sum()

# %% [markdown]
# ## Distribuccion de edad de las victimas

# %%
import plotly.express as px

fig = px.histogram(l_2021, x="edad_persona_en_situacion_de_violencia", nbins=30, title="Distribución de la Edad de las victimas")

fig.update_layout(
    xaxis_title="Edad",
    yaxis_title="Frecuencia",
    bargap=0.1,
    plot_bgcolor="white",
    xaxis=dict(
        showline=True,
        showgrid=True,
        gridcolor="lightgrey",
    ),
    yaxis=dict(
        showline=True,
        showgrid=True,
        gridcolor="lightgrey",
    )
)

fig.show()
